# %%
import os
import datetime
print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))

import time
import glob
import tables as tb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
# Out:
# 2017-07-25 23:30:16

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
from invisible_cities.database import load_db

import invisible_cities.sierpe.blr as blr

import invisible_cities.reco.tbl_functions as tbl
import invisible_cities.reco.peak_functions as pf
import invisible_cities.reco.peak_functions_c as cpf

from   invisible_cities.evm.ic_containers           import S12Params 
from   invisible_cities.evm.ic_containers          import CalibVectors
from   invisible_cities.evm.ic_containers          import DeconvParams
from   invisible_cities.evm.ic_containers          import ThresholdParams

from   invisible_cities.core.system_of_units_c import units
from   invisible_cities.types.ic_types import minmax
from   invisible_cities.types.ic_types import Counter
import invisible_cities.icaro.mpl_functions as mpl
from invisible_cities.icaro.pmaps_mpl import plot_s12
from invisible_cities.icaro.pmaps_mpl import plot_s2si_map

# %%
import invisible_cities.icaro.mpl_functions as mpl

# %%
import invisible_cities.evm.event_model as evm

# %%
from invisible_cities.evm.pmaps import S12
from invisible_cities.evm.pmaps import S1
from invisible_cities.evm.pmaps import S2
from invisible_cities.evm.pmaps import S2Si

# %%
from invisible_cities.core.exceptions        import SipmEmptyList
from invisible_cities.core.exceptions        import SipmNotFound
from invisible_cities.core.exceptions        import PeakNotFound

# %%
run_number = -4446
DataPMT = load_db.DataPMT(run_number)
DataSiPM = load_db.DataSiPM(run_number)
xs = DataSiPM.X.values
ys = DataSiPM.Y.values
pmt_active = np.nonzero(DataPMT.Active.values)[0].tolist()

# %%
channel_id = DataPMT.ChannelID.values
coeff_blr = abs(DataPMT.coeff_blr.values)
coeff_c = abs(DataPMT.coeff_c .values)
adc_to_pes = abs(DataPMT.adc_to_pes.values)
adc_to_pes_sipm = abs(DataSiPM.adc_to_pes.values)

# %%
RWF_file = os.path.join(os.environ['IC_DATA'], 'MC_PreProd_July_2017',
                        'dst_NEXT_v1_00_05_Tl_ACTIVE_0_0_7bar_RWF_10.h5')
print('RWF file = {}'.format(RWF_file))
# Out:
# RWF file = /Users/jjgomezcadenas/Projects/ICDATA/MC_PreProd_July_2017/dst_NEXT_v1_00_05_Tl_ACTIVE_0_0_7bar_RWF_10.h5

# %%
pmtrwf, pmtblr, sipmrwf = tbl.get_vectors(h5rwf)
NEVT, pmtrwf, sipmrwf, _ = tbl.get_rwf_vectors(h5rwf)
sp = tbl.get_sensor_params_from_vectors(pmtrwf, sipmrwf)
print(sp)
# Out:
# ####################
# SensorParams
# ####################
# npmt: 12
# pmtwl: 48000
# nsipm: 1792
# sipmwl: 1200

# %% [markdown]
# ### Reconstruction Parameters

# %%
h5rwf = tb.open_file(RWF_file,'r')

# %%
calib_vectors = CalibVectors(channel_id = DataPMT.ChannelID.values,
                             coeff_blr = abs(DataPMT.coeff_blr   .values),
                             coeff_c = abs(DataPMT.coeff_c   .values),
                             adc_to_pes = DataPMT.adc_to_pes.values,
                             adc_to_pes_sipm = DataSiPM.adc_to_pes.values,
                             pmt_active = np.nonzero(DataPMT.Active.values)[0].tolist())


deconv_params = DeconvParams(n_baseline = 45000,
                              thr_trigger = 5)

s1par = S12Params(time = minmax(min    = 99 * units.mus,
                           max    = 101 * units.mus),
                           stride = 4,
                           length = minmax(min = 6, max = 20),  #150 ns -- 500 ns
                           rebin  = False)

s2par = S12Params(time = minmax(min    = 101 * units.mus,
                           max    = 1199 * units.mus),
                           stride = 40,
                           length = minmax(min = 120, max = 1e5),  # 4 mus --
                           rebin  = True)

thresholds = ThresholdParams(thr_s1=0.5 * units.pes,
                      thr_s2=1.0 * units.pes,
                      thr_MAU=3*units.adc,
                      thr_sipm=1.5*units.pes,
                      thr_SIPM=15*units.pes)

# %%
event = 0

# %%
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))

# %% [markdown]
# #### Deconvolution

# %%
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)

# %% [markdown]
# #### csum

# %%
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)

# %%
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))

# %% [markdown]
# #### S1 and S2

# %%
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)

# %%
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())

# %%
s1
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 15 width =      0.3 mus , energy =     55.3 pes
#         height =      8.3 pes tmin-tmax = minmax(min=100.05, max=100.4) mus

# %%
plot_s12(s1)

# %%
s2
# Out:
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 15 width =     13.5 mus , energy =   9671.3 pes
#         height =   1639.3 pes tmin-tmax = minmax(min=465.9375, max=479.4125) mus

# %%
plot_s12(s2)

# %% [markdown]
# #### S2Si

# %%
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)

# %%
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)

# %%
s2si
# Out:
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 15 width =     13.5 mus , energy =   9671.3 pes
#         height =   1639.3 pes tmin-tmax = minmax(min=465.9375, max=479.4125) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1602, 1608, 1609, 1610, 1611, 1616, 1617, 1618, 1619, 1620, 1625, 1626, 1627, 1634)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1602
#     sipm waveform (zs) = Peak(samples = 6 width =      7.0 mus , energy =     23.4 pes
#         height =      7.7 pes tmin-tmax = minmax(min=468.5, max=475.5) mus
# peak number = 0: sipm number = 1608
#     sipm waveform (zs) = Peak(samples = 4 width =      3.0 mus , energy =     18.4 pes
#         height =      7.0 pes tmin-tmax = minmax(min=472.5, max=475.5) mus
# peak number = 0: sipm number = 1609
#     sipm waveform (zs) = Peak(samples = 11 width =     10.0 mus , energy =     95.8 pes
#         height =     18.9 pes tmin-tmax = minmax(min=467.5, max=477.5) mus
# peak number = 0: sipm number = 1610
#     sipm waveform (zs) = Peak(samples = 11 width =     10.0 mus , energy =    161.1 pes
#         height =     29.8 pes tmin-tmax = minmax(min=467.5, max=477.5) mus
# peak number = 0: sipm number = 1611
#     sipm waveform (zs) = Peak(samples = 11 width =     10.6 mus , energy =     76.4 pes
#         height =     17.0 pes tmin-tmax = minmax(min=465.9375, max=476.5) mus
# peak number = 0: sipm number = 1616
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     19.6 pes
#         height =      5.1 pes tmin-tmax = minmax(min=472.5, max=476.5) mus
# peak number = 0: sipm number = 1617
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =    161.1 pes
#         height =     33.2 pes tmin-tmax = minmax(min=467.5, max=476.5) mus
# peak number = 0: sipm number = 1618
#     sipm waveform (zs) = Peak(samples = 12 width =     11.0 mus , energy =    343.7 pes
#         height =     66.7 pes tmin-tmax = minmax(min=466.5, max=477.5) mus
# peak number = 0: sipm number = 1619
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =    153.0 pes
#         height =     29.6 pes tmin-tmax = minmax(min=466.5, max=475.5) mus
# peak number = 0: sipm number = 1620
#     sipm waveform (zs) = Peak(samples = 5 width =      5.0 mus , energy =     19.4 pes
#         height =      9.0 pes tmin-tmax = minmax(min=467.5, max=472.5) mus
# peak number = 0: sipm number = 1625
#     sipm waveform (zs) = Peak(samples = 10 width =     10.0 mus , energy =     84.5 pes
#         height =     15.8 pes tmin-tmax = minmax(min=466.5, max=476.5) mus
# peak number = 0: sipm number = 1626
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =    151.7 pes
#         height =     30.8 pes tmin-tmax = minmax(min=466.5, max=475.5) mus
# peak number = 0: sipm number = 1627
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =     80.5 pes
#         height =     17.9 pes tmin-tmax = minmax(min=467.5, max=475.5) mus
# peak number = 0: sipm number = 1634
#     sipm waveform (zs) = Peak(samples = 5 width =      7.0 mus , energy =     15.8 pes
#         height =      6.0 pes tmin-tmax = minmax(min=467.5, max=474.5) mus
# ================================================================================

# %%
s2si.number_of_peaks
# Out:
# 1

# %%
s2si.sipms_in_peak(0)
# Out:
# (1602,
#  1608,
#  1609,
#  1610,
#  1611,
#  1616,
#  1617,
#  1618,
#  1619,
#  1620,
#  1625,
#  1626,
#  1627,
#  1634)

# %%
plot_s2si_map(s2si, run_number=-4446)

# %%
event = 1
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 16 width =      0.4 mus , energy =     94.6 pes
#         height =     14.3 pes tmin-tmax = minmax(min=100.05, max=100.425) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 19 width =     17.6 mus , energy =  16352.0 pes
#         height =   2387.7 pes tmin-tmax = minmax(min=585.625, max=603.1750000000001) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 19 width =     17.6 mus , energy =  16352.0 pes
#         height =   2387.7 pes tmin-tmax = minmax(min=585.625, max=603.1750000000001) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1496, 1504, 1505, 1512, 1513, 1520, 1521, 1528, 1574, 1575, 1582, 1583, 1590, 1591, 1599)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1496
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     31.6 pes
#         height =      7.0 pes tmin-tmax = minmax(min=588.5, max=594.5) mus
# peak number = 0: sipm number = 1504
#     sipm waveform (zs) = Peak(samples = 14 width =     13.0 mus , energy =    206.4 pes
#         height =     33.7 pes tmin-tmax = minmax(min=587.5, max=600.5) mus
# peak number = 0: sipm number = 1505
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =     69.9 pes
#         height =     16.0 pes tmin-tmax = minmax(min=588.5, max=597.5) mus
# peak number = 0: sipm number = 1512
#     sipm waveform (zs) = Peak(samples = 15 width =     14.9 mus , energy =    389.3 pes
#         height =     62.9 pes tmin-tmax = minmax(min=585.625, max=600.5) mus
# peak number = 0: sipm number = 1513
#     sipm waveform (zs) = Peak(samples = 11 width =     10.0 mus , energy =    117.0 pes
#         height =     18.8 pes tmin-tmax = minmax(min=587.5, max=597.5) mus
# peak number = 0: sipm number = 1520
#     sipm waveform (zs) = Peak(samples = 14 width =     14.0 mus , energy =    207.1 pes
#         height =     40.8 pes tmin-tmax = minmax(min=586.5, max=600.5) mus
# peak number = 0: sipm number = 1521
#     sipm waveform (zs) = Peak(samples = 14 width =     15.0 mus , energy =     65.7 pes
#         height =     12.1 pes tmin-tmax = minmax(min=586.5, max=601.5) mus
# peak number = 0: sipm number = 1528
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =     37.7 pes
#         height =      9.1 pes tmin-tmax = minmax(min=588.5, max=597.5) mus
# peak number = 0: sipm number = 1574
#     sipm waveform (zs) = Peak(samples = 7 width =      8.0 mus , energy =     27.6 pes
#         height =      8.0 pes tmin-tmax = minmax(min=587.5, max=595.5) mus
# peak number = 0: sipm number = 1575
#     sipm waveform (zs) = Peak(samples = 13 width =     12.0 mus , energy =    158.4 pes
#         height =     25.9 pes tmin-tmax = minmax(min=586.5, max=598.5) mus
# peak number = 0: sipm number = 1582
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =     55.2 pes
#         height =      9.9 pes tmin-tmax = minmax(min=589.5, max=596.5) mus
# peak number = 0: sipm number = 1583
#     sipm waveform (zs) = Peak(samples = 15 width =     14.0 mus , energy =    306.8 pes
#         height =     51.7 pes tmin-tmax = minmax(min=586.5, max=600.5) mus
# peak number = 0: sipm number = 1590
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =     28.9 pes
#         height =      7.9 pes tmin-tmax = minmax(min=589.5, max=596.5) mus
# peak number = 0: sipm number = 1591
#     sipm waveform (zs) = Peak(samples = 14 width =     15.0 mus , energy =    189.9 pes
#         height =     37.8 pes tmin-tmax = minmax(min=587.5, max=602.5) mus
# peak number = 0: sipm number = 1599
#     sipm waveform (zs) = Peak(samples = 8 width =      8.0 mus , energy =     27.0 pes
#         height =      6.0 pes tmin-tmax = minmax(min=590.5, max=598.5) mus
# ================================================================================
# 1

# %%
event = 2
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 10 width =      0.2 mus , energy =     17.7 pes
#         height =      3.2 pes tmin-tmax = minmax(min=100.075, max=100.3) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 10 width =      8.5 mus , energy =   6265.1 pes
#         height =   1455.5 pes tmin-tmax = minmax(min=327.875, max=336.33750000000003) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 10 width =      8.5 mus , energy =   6265.1 pes
#         height =   1455.5 pes tmin-tmax = minmax(min=327.875, max=336.33750000000003) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (419, 420, 427, 428, 429, 435, 436, 707, 708, 715, 716)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 419
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     15.5 pes
#         height =      4.0 pes tmin-tmax = minmax(min=329.5, max=333.5) mus
# peak number = 0: sipm number = 420
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     30.6 pes
#         height =      7.9 pes tmin-tmax = minmax(min=329.5, max=333.5) mus
# peak number = 0: sipm number = 427
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     44.3 pes
#         height =     13.9 pes tmin-tmax = minmax(min=329.5, max=333.5) mus
# peak number = 0: sipm number = 428
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     86.4 pes
#         height =     25.9 pes tmin-tmax = minmax(min=328.5, max=334.5) mus
# peak number = 0: sipm number = 429
#     sipm waveform (zs) = Peak(samples = 3 width =      2.0 mus , energy =     18.5 pes
#         height =      7.7 pes tmin-tmax = minmax(min=330.5, max=332.5) mus
# peak number = 0: sipm number = 435
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     28.0 pes
#         height =      7.8 pes tmin-tmax = minmax(min=329.5, max=333.5) mus
# peak number = 0: sipm number = 436
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     32.7 pes
#         height =      7.9 pes tmin-tmax = minmax(min=329.5, max=333.5) mus
# peak number = 0: sipm number = 707
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     36.0 pes
#         height =     10.9 pes tmin-tmax = minmax(min=330.5, max=334.5) mus
# peak number = 0: sipm number = 708
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     46.2 pes
#         height =     10.9 pes tmin-tmax = minmax(min=329.5, max=334.5) mus
# peak number = 0: sipm number = 715
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     41.9 pes
#         height =     11.7 pes tmin-tmax = minmax(min=329.5, max=334.5) mus
# peak number = 0: sipm number = 716
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     65.5 pes
#         height =     22.0 pes tmin-tmax = minmax(min=329.5, max=334.5) mus
# ================================================================================
# 1

# %%
event = 3
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 11 width =      0.2 mus , energy =     28.6 pes
#         height =      5.0 pes tmin-tmax = minmax(min=100.075, max=100.325) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 19 width =     17.6 mus , energy =  10954.4 pes
#         height =   1986.7 pes tmin-tmax = minmax(min=308.77500000000003, max=326.4125) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 19 width =     17.6 mus , energy =  10954.4 pes
#         height =   1986.7 pes tmin-tmax = minmax(min=308.77500000000003, max=326.4125) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1140, 1141, 1147, 1148, 1149, 1150, 1408, 1409, 1416, 1417, 1479)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1140
#     sipm waveform (zs) = Peak(samples = 12 width =     16.0 mus , energy =     88.8 pes
#         height =     15.8 pes tmin-tmax = minmax(min=309.5, max=325.5) mus
# peak number = 0: sipm number = 1141
#     sipm waveform (zs) = Peak(samples = 9 width =     13.0 mus , energy =     55.5 pes
#         height =     11.1 pes tmin-tmax = minmax(min=311.5, max=324.5) mus
# peak number = 0: sipm number = 1147
#     sipm waveform (zs) = Peak(samples = 9 width =     14.0 mus , energy =     63.2 pes
#         height =     15.0 pes tmin-tmax = minmax(min=309.5, max=323.5) mus
# peak number = 0: sipm number = 1148
#     sipm waveform (zs) = Peak(samples = 14 width =     16.7 mus , energy =    236.8 pes
#         height =     53.6 pes tmin-tmax = minmax(min=308.77500000000003, max=325.5) mus
# peak number = 0: sipm number = 1149
#     sipm waveform (zs) = Peak(samples = 13 width =     15.0 mus , energy =    122.9 pes
#         height =     19.9 pes tmin-tmax = minmax(min=309.5, max=324.5) mus
# peak number = 0: sipm number = 1150
#     sipm waveform (zs) = Peak(samples = 7 width =     13.0 mus , energy =     24.9 pes
#         height =      5.1 pes tmin-tmax = minmax(min=311.5, max=324.5) mus
# peak number = 0: sipm number = 1408
#     sipm waveform (zs) = Peak(samples = 10 width =     14.0 mus , energy =    186.1 pes
#         height =     45.9 pes tmin-tmax = minmax(min=309.5, max=323.5) mus
# peak number = 0: sipm number = 1409
#     sipm waveform (zs) = Peak(samples = 9 width =     13.0 mus , energy =    106.3 pes
#         height =     33.1 pes tmin-tmax = minmax(min=310.5, max=323.5) mus
# peak number = 0: sipm number = 1416
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     30.7 pes
#         height =      9.9 pes tmin-tmax = minmax(min=310.5, max=314.5) mus
# peak number = 0: sipm number = 1417
#     sipm waveform (zs) = Peak(samples = 5 width =      5.0 mus , energy =     15.8 pes
#         height =      3.9 pes tmin-tmax = minmax(min=309.5, max=314.5) mus
# peak number = 0: sipm number = 1479
#     sipm waveform (zs) = Peak(samples = 7 width =     12.0 mus , energy =     53.9 pes
#         height =     16.1 pes tmin-tmax = minmax(min=310.5, max=322.5) mus
# ================================================================================
# 1

# %%
event = 4
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 0)
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 74 width =     72.7 mus , energy =  96632.5 pes
#         height =   6645.6 pes tmin-tmax = minmax(min=436.7375, max=509.4125) mus
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-41-35281d6b5ed7> in <module>()
#      22 print(s1)
#      23 print(s2)
# ---> 24 plot_s12(s1)
#      25 plot_s12(s2)
#      26 sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
#
# /Users/jjgomezcadenas/Projects/IC/invisible_cities/icaro/pmaps_mpl.py in plot_s12(s12, figsize)
#      32         x = 3
#      33         y = xy/x
# ---> 34         if y % xy != 0:
#      35             y = int(xy/x) + 1
#      36         for i in range(xy):
#
# ZeroDivisionError: float modulo

# %%
event = 5
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 7 width =      0.1 mus , energy =     14.9 pes
#         height =      2.8 pes tmin-tmax = minmax(min=100.075, max=100.22500000000001) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 11 width =      9.4 mus , energy =   3372.0 pes
#         height =    689.1 pes tmin-tmax = minmax(min=496.96250000000003, max=506.325) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 11 width =      9.4 mus , energy =   3372.0 pes
#         height =    689.1 pes tmin-tmax = minmax(min=496.96250000000003, max=506.325) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1493, 1494, 1501, 1502, 1503, 1509, 1510, 1511)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1493
#     sipm waveform (zs) = Peak(samples = 5 width =      5.0 mus , energy =     16.6 pes
#         height =      5.0 pes tmin-tmax = minmax(min=498.5, max=503.5) mus
# peak number = 0: sipm number = 1494
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     19.5 pes
#         height =      7.8 pes tmin-tmax = minmax(min=499.5, max=503.5) mus
# peak number = 0: sipm number = 1501
#     sipm waveform (zs) = Peak(samples = 8 width =      8.5 mus , energy =     48.6 pes
#         height =     13.0 pes tmin-tmax = minmax(min=496.96250000000003, max=505.5) mus
# peak number = 0: sipm number = 1502
#     sipm waveform (zs) = Peak(samples = 6 width =      6.0 mus , energy =     71.6 pes
#         height =     20.8 pes tmin-tmax = minmax(min=497.5, max=503.5) mus
# peak number = 0: sipm number = 1503
#     sipm waveform (zs) = Peak(samples = 4 width =      4.0 mus , energy =     20.2 pes
#         height =      7.8 pes tmin-tmax = minmax(min=498.5, max=502.5) mus
# peak number = 0: sipm number = 1509
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     34.6 pes
#         height =      8.8 pes tmin-tmax = minmax(min=498.5, max=504.5) mus
# peak number = 0: sipm number = 1510
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =     66.4 pes
#         height =     17.9 pes tmin-tmax = minmax(min=498.5, max=505.5) mus
# peak number = 0: sipm number = 1511
#     sipm waveform (zs) = Peak(samples = 5 width =      7.0 mus , energy =     17.1 pes
#         height =      5.1 pes tmin-tmax = minmax(min=498.5, max=505.5) mus
# ================================================================================
# 1

# %%
event = 6
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 16 width =      0.4 mus , energy =     65.5 pes
#         height =      9.3 pes tmin-tmax = minmax(min=100.05, max=100.425) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 15 width =     13.6 mus , energy =  20346.3 pes
#         height =   3818.9 pes tmin-tmax = minmax(min=388.9125, max=402.46250000000003) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 15 width =     13.6 mus , energy =  20346.3 pes
#         height =   3818.9 pes tmin-tmax = minmax(min=388.9125, max=402.46250000000003) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (404, 411, 412, 413, 418, 419, 420, 421, 422, 427, 428, 429, 430, 436, 437)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 404
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     15.2 pes
#         height =      5.0 pes tmin-tmax = minmax(min=392.5, max=396.5) mus
# peak number = 0: sipm number = 411
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =     96.9 pes
#         height =     28.0 pes tmin-tmax = minmax(min=392.5, max=399.5) mus
# peak number = 0: sipm number = 412
#     sipm waveform (zs) = Peak(samples = 11 width =     10.0 mus , energy =    195.6 pes
#         height =     45.9 pes tmin-tmax = minmax(min=390.5, max=400.5) mus
# peak number = 0: sipm number = 413
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =    100.1 pes
#         height =     19.9 pes tmin-tmax = minmax(min=390.5, max=398.5) mus
# peak number = 0: sipm number = 418
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     31.1 pes
#         height =     11.1 pes tmin-tmax = minmax(min=393.5, max=398.5) mus
# peak number = 0: sipm number = 419
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =    235.9 pes
#         height =     48.8 pes tmin-tmax = minmax(min=391.5, max=399.5) mus
# peak number = 0: sipm number = 420
#     sipm waveform (zs) = Peak(samples = 12 width =     11.0 mus , energy =    519.0 pes
#         height =    110.7 pes tmin-tmax = minmax(min=390.5, max=401.5) mus
# peak number = 0: sipm number = 421
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =    229.0 pes
#         height =     39.9 pes tmin-tmax = minmax(min=390.5, max=399.5) mus
# peak number = 0: sipm number = 422
#     sipm waveform (zs) = Peak(samples = 8 width =      8.0 mus , energy =     67.7 pes
#         height =     17.9 pes tmin-tmax = minmax(min=389.5, max=397.5) mus
# peak number = 0: sipm number = 427
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =    103.6 pes
#         height =     22.0 pes tmin-tmax = minmax(min=391.5, max=400.5) mus
# peak number = 0: sipm number = 428
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =    223.3 pes
#         height =     55.8 pes tmin-tmax = minmax(min=391.5, max=399.5) mus
# peak number = 0: sipm number = 429
#     sipm waveform (zs) = Peak(samples = 11 width =     11.0 mus , energy =    136.3 pes
#         height =     25.8 pes tmin-tmax = minmax(min=389.5, max=400.5) mus
# peak number = 0: sipm number = 430
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     36.3 pes
#         height =     10.1 pes tmin-tmax = minmax(min=390.5, max=396.5) mus
# peak number = 0: sipm number = 436
#     sipm waveform (zs) = Peak(samples = 5 width =      5.0 mus , energy =     20.8 pes
#         height =      6.0 pes tmin-tmax = minmax(min=393.5, max=398.5) mus
# peak number = 0: sipm number = 437
#     sipm waveform (zs) = Peak(samples = 5 width =      6.0 mus , energy =     15.1 pes
#         height =      6.0 pes tmin-tmax = minmax(min=389.5, max=395.5) mus
# ================================================================================
# 1

# %%
event = 7
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 13 width =      0.3 mus , energy =     25.1 pes
#         height =      4.2 pes tmin-tmax = minmax(min=100.075, max=100.375) mus
#
# S2 (number of peaks = 2)
# peak number = 0: Peak(samples = 7 width =      5.5 mus , energy =   2895.6 pes
#         height =    940.4 pes tmin-tmax = minmax(min=202.6875, max=208.1625) mus
# peak number = 1: Peak(samples = 9 width =      7.5 mus , energy =  13129.4 pes
#         height =   3905.7 pes tmin-tmax = minmax(min=238.8, max=246.275) mus
#
# ================================================================================
# S2 (number of peaks = 2)
# peak number = 0: Peak(samples = 7 width =      5.5 mus , energy =   2895.6 pes
#         height =    940.4 pes tmin-tmax = minmax(min=202.6875, max=208.1625) mus
# peak number = 1: Peak(samples = 9 width =      7.5 mus , energy =  13129.4 pes
#         height =   3905.7 pes tmin-tmax = minmax(min=238.8, max=246.275) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (401, 402, 403, 410, 411)
#
# peak number = 1: nsipm in peak = (396, 403, 404, 405, 411, 412, 413, 419, 420, 421)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 401
#     sipm waveform (zs) = Peak(samples = 4 width =      2.8 mus , energy =     15.6 pes
#         height =      6.0 pes tmin-tmax = minmax(min=202.6875, max=205.5) mus
# peak number = 0: sipm number = 402
#     sipm waveform (zs) = Peak(samples = 5 width =      3.8 mus , energy =    116.6 pes
#         height =     43.8 pes tmin-tmax = minmax(min=202.6875, max=206.5) mus
# peak number = 0: sipm number = 403
#     sipm waveform (zs) = Peak(samples = 5 width =      3.8 mus , energy =     38.2 pes
#         height =     10.9 pes tmin-tmax = minmax(min=202.6875, max=206.5) mus
# peak number = 0: sipm number = 410
#     sipm waveform (zs) = Peak(samples = 5 width =      3.8 mus , energy =     52.1 pes
#         height =     18.8 pes tmin-tmax = minmax(min=202.6875, max=206.5) mus
# peak number = 0: sipm number = 411
#     sipm waveform (zs) = Peak(samples = 4 width =      3.0 mus , energy =     22.3 pes
#         height =      9.6 pes tmin-tmax = minmax(min=203.5, max=206.5) mus
# peak number = 1: sipm number = 396
#     sipm waveform (zs) = Peak(samples = 4 width =      3.0 mus , energy =     31.9 pes
#         height =     13.0 pes tmin-tmax = minmax(min=239.5, max=242.5) mus
# peak number = 1: sipm number = 403
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     80.2 pes
#         height =     26.0 pes tmin-tmax = minmax(min=239.5, max=244.5) mus
# peak number = 1: sipm number = 404
#     sipm waveform (zs) = Peak(samples = 8 width =      6.7 mus , energy =    226.6 pes
#         height =     64.9 pes tmin-tmax = minmax(min=238.8, max=245.5) mus
# peak number = 1: sipm number = 405
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     79.9 pes
#         height =     30.7 pes tmin-tmax = minmax(min=239.5, max=244.5) mus
# peak number = 1: sipm number = 411
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =    148.3 pes
#         height =     62.8 pes tmin-tmax = minmax(min=239.5, max=244.5) mus
# peak number = 1: sipm number = 412
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =    501.4 pes
#         height =    170.5 pes tmin-tmax = minmax(min=239.5, max=245.5) mus
# peak number = 1: sipm number = 413
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =    141.7 pes
#         height =     44.6 pes tmin-tmax = minmax(min=239.5, max=244.5) mus
# peak number = 1: sipm number = 419
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     37.1 pes
#         height =     13.7 pes tmin-tmax = minmax(min=240.5, max=244.5) mus
# peak number = 1: sipm number = 420
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     78.9 pes
#         height =     29.9 pes tmin-tmax = minmax(min=240.5, max=244.5) mus
# peak number = 1: sipm number = 421
#     sipm waveform (zs) = Peak(samples = 4 width =      3.0 mus , energy =     32.3 pes
#         height =     15.8 pes tmin-tmax = minmax(min=240.5, max=243.5) mus
# ================================================================================
# 2

# %%
event = 8
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 10 width =      0.2 mus , energy =     22.8 pes
#         height =      3.6 pes tmin-tmax = minmax(min=100.05, max=100.275) mus
#
# S2 (number of peaks = 2)
# peak number = 0: Peak(samples = 11 width =      9.8 mus , energy =   6136.3 pes
#         height =   1325.9 pes tmin-tmax = minmax(min=424.55, max=434.3) mus
# peak number = 1: Peak(samples = 10 width =      8.7 mus , energy =   1805.5 pes
#         height =    417.1 pes tmin-tmax = minmax(min=459.58750000000003, max=468.2625) mus
#
# ================================================================================
# S2 (number of peaks = 2)
# peak number = 0: Peak(samples = 11 width =      9.8 mus , energy =   6136.3 pes
#         height =   1325.9 pes tmin-tmax = minmax(min=424.55, max=434.3) mus
# peak number = 1: Peak(samples = 10 width =      8.7 mus , energy =   1805.5 pes
#         height =    417.1 pes tmin-tmax = minmax(min=459.58750000000003, max=468.2625) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1467, 1468, 1666, 1667, 1668, 1674, 1675, 1676, 1683)
#
# peak number = 1: nsipm in peak = (1608, 1616, 1624, 1679, 1687)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1467
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     23.0 pes
#         height =      5.9 pes tmin-tmax = minmax(min=426.5, max=431.5) mus
# peak number = 0: sipm number = 1468
#     sipm waveform (zs) = Peak(samples = 4 width =      3.0 mus , energy =     19.1 pes
#         height =      5.7 pes tmin-tmax = minmax(min=426.5, max=429.5) mus
# peak number = 0: sipm number = 1666
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     37.6 pes
#         height =     14.9 pes tmin-tmax = minmax(min=426.5, max=431.5) mus
# peak number = 0: sipm number = 1667
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =    142.1 pes
#         height =     31.9 pes tmin-tmax = minmax(min=424.55, max=432.5) mus
# peak number = 0: sipm number = 1668
#     sipm waveform (zs) = Peak(samples = 10 width =      9.8 mus , energy =    107.4 pes
#         height =     30.6 pes tmin-tmax = minmax(min=424.55, max=434.3) mus
# peak number = 0: sipm number = 1674
#     sipm waveform (zs) = Peak(samples = 5 width =      5.0 mus , energy =     30.4 pes
#         height =     12.8 pes tmin-tmax = minmax(min=425.5, max=430.5) mus
# peak number = 0: sipm number = 1675
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =    131.9 pes
#         height =     34.9 pes tmin-tmax = minmax(min=424.55, max=431.5) mus
# peak number = 0: sipm number = 1676
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =    100.8 pes
#         height =     21.9 pes tmin-tmax = minmax(min=425.5, max=433.5) mus
# peak number = 0: sipm number = 1683
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     25.9 pes
#         height =      8.1 pes tmin-tmax = minmax(min=426.5, max=430.5) mus
# peak number = 1: sipm number = 1608
#     sipm waveform (zs) = Peak(samples = 5 width =      5.0 mus , energy =     26.7 pes
#         height =      8.8 pes tmin-tmax = minmax(min=461.5, max=466.5) mus
# peak number = 1: sipm number = 1616
#     sipm waveform (zs) = Peak(samples = 7 width =      5.9 mus , energy =     56.7 pes
#         height =     15.8 pes tmin-tmax = minmax(min=459.58750000000003, max=465.5) mus
# peak number = 1: sipm number = 1624
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     19.9 pes
#         height =      7.0 pes tmin-tmax = minmax(min=460.5, max=464.5) mus
# peak number = 1: sipm number = 1679
#     sipm waveform (zs) = Peak(samples = 6 width =      5.9 mus , energy =     19.7 pes
#         height =      7.0 pes tmin-tmax = minmax(min=459.58750000000003, max=465.5) mus
# peak number = 1: sipm number = 1687
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     41.8 pes
#         height =     15.0 pes tmin-tmax = minmax(min=461.5, max=465.5) mus
# ================================================================================
# 2
