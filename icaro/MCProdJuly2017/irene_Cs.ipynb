# %%
import os
import datetime
print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))

import time
import glob
import tables as tb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
# Out:
# 2017-07-25 23:11:57

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
from invisible_cities.database import load_db

import invisible_cities.sierpe.blr as blr

import invisible_cities.reco.tbl_functions as tbl
import invisible_cities.reco.peak_functions as pf
import invisible_cities.reco.peak_functions_c as cpf

from   invisible_cities.evm.ic_containers           import S12Params 
from   invisible_cities.evm.ic_containers          import CalibVectors
from   invisible_cities.evm.ic_containers          import DeconvParams
from   invisible_cities.evm.ic_containers          import ThresholdParams

from   invisible_cities.core.system_of_units_c import units
from   invisible_cities.types.ic_types import minmax
from   invisible_cities.types.ic_types import Counter
import invisible_cities.icaro.mpl_functions as mpl
from invisible_cities.icaro.pmaps_mpl import plot_s12
from invisible_cities.icaro.pmaps_mpl import plot_s2si_map

# %%
import invisible_cities.icaro.mpl_functions as mpl

# %%
import invisible_cities.evm.event_model as evm

# %%
from invisible_cities.evm.pmaps import S12
from invisible_cities.evm.pmaps import S1
from invisible_cities.evm.pmaps import S2
from invisible_cities.evm.pmaps import S2Si

# %%
from invisible_cities.core.exceptions        import SipmEmptyList
from invisible_cities.core.exceptions        import SipmNotFound
from invisible_cities.core.exceptions        import PeakNotFound

# %%
run_number = -4446
DataPMT = load_db.DataPMT(run_number)
DataSiPM = load_db.DataSiPM(run_number)
xs = DataSiPM.X.values
ys = DataSiPM.Y.values
pmt_active = np.nonzero(DataPMT.Active.values)[0].tolist()

# %%
channel_id = DataPMT.ChannelID.values
coeff_blr = abs(DataPMT.coeff_blr.values)
coeff_c = abs(DataPMT.coeff_c .values)
adc_to_pes = abs(DataPMT.adc_to_pes.values)
adc_to_pes_sipm = abs(DataSiPM.adc_to_pes.values)

# %%
RWF_file = os.path.join(os.environ['IC_DATA'], 'MC_PreProd_July_2017',
                        'dst_NEXT_v1_00_05_Cs_ACTIVE_0_0_7bar_RWF_10.h5')
print('RWF file = {}'.format(RWF_file))
# Out:
# RWF file = /Users/jjgomezcadenas/Projects/ICDATA/MC_PreProd_July_2017/dst_NEXT_v1_00_05_Cs_ACTIVE_0_0_7bar_RWF_10.h5

# %%
h5rwf = tb.open_file(RWF_file,'r')

# %%
pmtrwf, pmtblr, sipmrwf = tbl.get_vectors(h5rwf)
NEVT, pmtrwf, sipmrwf, _ = tbl.get_rwf_vectors(h5rwf)
sp = tbl.get_sensor_params_from_vectors(pmtrwf, sipmrwf)
print(sp)
# Out:
# ####################
# SensorParams
# ####################
# npmt: 12
# pmtwl: 48000
# nsipm: 1792
# sipmwl: 1200

# %% [markdown]
# ### Reconstruction Parameters

# %%
calib_vectors = CalibVectors(channel_id = DataPMT.ChannelID.values,
                             coeff_blr = abs(DataPMT.coeff_blr   .values),
                             coeff_c = abs(DataPMT.coeff_c   .values),
                             adc_to_pes = DataPMT.adc_to_pes.values,
                             adc_to_pes_sipm = DataSiPM.adc_to_pes.values,
                             pmt_active = np.nonzero(DataPMT.Active.values)[0].tolist())


deconv_params = DeconvParams(n_baseline = 45000,
                              thr_trigger = 5)

s1par = S12Params(time = minmax(min    = 99 * units.mus,
                           max    = 101 * units.mus),
                           stride = 4,
                           length = minmax(min = 6, max = 30),  #150 ns -- 500 ns
                           rebin  = False)

s2par = S12Params(time = minmax(min    = 101 * units.mus,
                           max    = 1199 * units.mus),
                           stride = 40,
                           length = minmax(min = 120, max = 1e5),  # 4 mus --
                           rebin  = True)

thresholds = ThresholdParams(thr_s1=2 * units.pes,
                      thr_s2=1.0 * units.pes,
                      thr_MAU=3*units.adc,
                      thr_sipm=1.5*units.pes,
                      thr_SIPM=15*units.pes)

# %%
event = 0

# %%
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))

# %% [markdown]
# #### Deconvolution

# %%
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)

# %% [markdown]
# #### csum

# %%
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)

# %%
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  60,
                        figsize=(6,6))

# %% [markdown]
# #### S1 and S2

# %%
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)

# %%
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())

# %%
s1
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 7 width =      0.1 mus , energy =     31.4 pes
#         height =      6.0 pes tmin-tmax = minmax(min=100.075, max=100.22500000000001) mus

# %%
plot_s12(s1)

# %%
s2
# Out:
# S2 (number of peaks = 2)
# peak number = 0: Peak(samples = 12 width =     10.8 mus , energy =   7367.8 pes
#         height =   1385.2 pes tmin-tmax = minmax(min=552.525, max=563.2875) mus
# peak number = 1: Peak(samples = 11 width =      9.4 mus , energy =   2134.1 pes
#         height =    370.0 pes tmin-tmax = minmax(min=599.8125, max=609.2) mus

# %%
plot_s12(s2)

# %% [markdown]
# #### S2Si

# %%
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)

# %%
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)

# %%
s2si
# Out:
# ================================================================================
# S2 (number of peaks = 2)
# peak number = 0: Peak(samples = 12 width =     10.8 mus , energy =   7367.8 pes
#         height =   1385.2 pes tmin-tmax = minmax(min=552.525, max=563.2875) mus
# peak number = 1: Peak(samples = 11 width =      9.4 mus , energy =   2134.1 pes
#         height =    370.0 pes tmin-tmax = minmax(min=599.8125, max=609.2) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1122, 1123, 1124, 1130, 1131, 1132, 1138, 1139, 1140, 1147)
#
# peak number = 1: nsipm in peak = (1134, 1135, 1142, 1143)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1122
#     sipm waveform (zs) = Peak(samples = 7 width =      7.0 mus , energy =     31.1 pes
#         height =      7.8 pes tmin-tmax = minmax(min=552.525, max=559.5) mus
# peak number = 0: sipm number = 1123
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     56.9 pes
#         height =     18.0 pes tmin-tmax = minmax(min=554.5, max=560.5) mus
# peak number = 0: sipm number = 1124
#     sipm waveform (zs) = Peak(samples = 7 width =     10.8 mus , energy =     27.5 pes
#         height =      7.0 pes tmin-tmax = minmax(min=552.525, max=563.2875) mus
# peak number = 0: sipm number = 1130
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =     99.8 pes
#         height =     18.1 pes tmin-tmax = minmax(min=552.525, max=560.5) mus
# peak number = 0: sipm number = 1131
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =    142.5 pes
#         height =     40.9 pes tmin-tmax = minmax(min=553.5, max=562.5) mus
# peak number = 0: sipm number = 1132
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     56.8 pes
#         height =     13.9 pes tmin-tmax = minmax(min=553.5, max=559.5) mus
# peak number = 0: sipm number = 1138
#     sipm waveform (zs) = Peak(samples = 8 width =      8.0 mus , energy =     49.6 pes
#         height =     15.7 pes tmin-tmax = minmax(min=553.5, max=561.5) mus
# peak number = 0: sipm number = 1139
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =    114.6 pes
#         height =     22.9 pes tmin-tmax = minmax(min=553.5, max=561.5) mus
# peak number = 0: sipm number = 1140
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     43.7 pes
#         height =     10.0 pes tmin-tmax = minmax(min=554.5, max=559.5) mus
# peak number = 0: sipm number = 1147
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     18.1 pes
#         height =      4.9 pes tmin-tmax = minmax(min=555.5, max=559.5) mus
# peak number = 1: sipm number = 1134
#     sipm waveform (zs) = Peak(samples = 7 width =      6.7 mus , energy =     38.8 pes
#         height =     10.8 pes tmin-tmax = minmax(min=599.8125, max=606.5) mus
# peak number = 1: sipm number = 1135
#     sipm waveform (zs) = Peak(samples = 7 width =      7.0 mus , energy =     20.4 pes
#         height =      5.0 pes tmin-tmax = minmax(min=601.5, max=608.5) mus
# peak number = 1: sipm number = 1142
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     27.7 pes
#         height =      8.9 pes tmin-tmax = minmax(min=600.5, max=606.5) mus
# peak number = 1: sipm number = 1143
#     sipm waveform (zs) = Peak(samples = 5 width =      6.0 mus , energy =     17.0 pes
#         height =      4.8 pes tmin-tmax = minmax(min=600.5, max=606.5) mus
# ================================================================================

# %%
s2si.number_of_peaks
# Out:
# 2

# %%
s2si.sipms_in_peak(0)
# Out:
# (1122, 1123, 1124, 1130, 1131, 1132, 1138, 1139, 1140, 1147)

# %%
plot_s2si_map(s2si, run_number=-4446)

# %%
event = 1
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  50,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      0.2 mus , energy =     44.6 pes
#         height =      7.5 pes tmin-tmax = minmax(min=100.075, max=100.25) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 13 width =     11.6 mus , energy =   8658.8 pes
#         height =   1488.9 pes tmin-tmax = minmax(min=589.725, max=601.3625000000001) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 13 width =     11.6 mus , energy =   8658.8 pes
#         height =   1488.9 pes tmin-tmax = minmax(min=589.725, max=601.3625000000001) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (104, 105, 112, 113, 114, 120, 121, 175, 183, 191, 320, 321, 391)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 104
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =     48.8 pes
#         height =     11.9 pes tmin-tmax = minmax(min=591.5, max=598.5) mus
# peak number = 0: sipm number = 105
#     sipm waveform (zs) = Peak(samples = 6 width =      6.0 mus , energy =     38.5 pes
#         height =     11.7 pes tmin-tmax = minmax(min=592.5, max=598.5) mus
# peak number = 0: sipm number = 112
#     sipm waveform (zs) = Peak(samples = 11 width =     10.0 mus , energy =    187.9 pes
#         height =     32.9 pes tmin-tmax = minmax(min=590.5, max=600.5) mus
# peak number = 0: sipm number = 113
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =    103.6 pes
#         height =     21.7 pes tmin-tmax = minmax(min=591.5, max=599.5) mus
# peak number = 0: sipm number = 114
#     sipm waveform (zs) = Peak(samples = 5 width =      5.0 mus , energy =     19.3 pes
#         height =      6.0 pes tmin-tmax = minmax(min=591.5, max=596.5) mus
# peak number = 0: sipm number = 120
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =    170.7 pes
#         height =     30.8 pes tmin-tmax = minmax(min=590.5, max=599.5) mus
# peak number = 0: sipm number = 121
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =     99.6 pes
#         height =     27.9 pes tmin-tmax = minmax(min=591.5, max=599.5) mus
# peak number = 0: sipm number = 175
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     15.5 pes
#         height =      3.9 pes tmin-tmax = minmax(min=593.5, max=597.5) mus
# peak number = 0: sipm number = 183
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =     76.8 pes
#         height =     18.9 pes tmin-tmax = minmax(min=591.5, max=598.5) mus
# peak number = 0: sipm number = 191
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =     58.7 pes
#         height =     13.0 pes tmin-tmax = minmax(min=591.5, max=598.5) mus
# peak number = 0: sipm number = 320
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =     55.0 pes
#         height =      9.9 pes tmin-tmax = minmax(min=591.5, max=600.5) mus
# peak number = 0: sipm number = 321
#     sipm waveform (zs) = Peak(samples = 7 width =      7.0 mus , energy =     27.4 pes
#         height =      7.9 pes tmin-tmax = minmax(min=592.5, max=599.5) mus
# peak number = 0: sipm number = 391
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     15.8 pes
#         height =      4.9 pes tmin-tmax = minmax(min=594.5, max=598.5) mus
# ================================================================================
# 1

# %%
event = 2
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 9 width =      0.2 mus , energy =     65.1 pes
#         height =     10.8 pes tmin-tmax = minmax(min=100.075, max=100.275) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 20 width =     18.4 mus , energy =  16316.5 pes
#         height =   2012.6 pes tmin-tmax = minmax(min=538.7375, max=557.0875) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 20 width =     18.4 mus , energy =  16316.5 pes
#         height =   2012.6 pes tmin-tmax = minmax(min=538.7375, max=557.0875) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (528, 536, 544, 598, 599, 605, 606, 607, 613, 614, 615, 621, 622, 623)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 528
#     sipm waveform (zs) = Peak(samples = 6 width =      7.0 mus , energy =     24.5 pes
#         height =      9.4 pes tmin-tmax = minmax(min=545.5, max=552.5) mus
# peak number = 0: sipm number = 536
#     sipm waveform (zs) = Peak(samples = 12 width =     12.0 mus , energy =     75.1 pes
#         height =     14.0 pes tmin-tmax = minmax(min=540.5, max=552.5) mus
# peak number = 0: sipm number = 544
#     sipm waveform (zs) = Peak(samples = 13 width =     12.0 mus , energy =     67.8 pes
#         height =     10.0 pes tmin-tmax = minmax(min=541.5, max=553.5) mus
# peak number = 0: sipm number = 598
#     sipm waveform (zs) = Peak(samples = 8 width =      8.0 mus , energy =     41.1 pes
#         height =      9.9 pes tmin-tmax = minmax(min=543.5, max=551.5) mus
# peak number = 0: sipm number = 599
#     sipm waveform (zs) = Peak(samples = 11 width =     12.0 mus , energy =     61.0 pes
#         height =     10.9 pes tmin-tmax = minmax(min=542.5, max=554.5) mus
# peak number = 0: sipm number = 605
#     sipm waveform (zs) = Peak(samples = 11 width =     10.0 mus , energy =     60.8 pes
#         height =     11.8 pes tmin-tmax = minmax(min=543.5, max=553.5) mus
# peak number = 0: sipm number = 606
#     sipm waveform (zs) = Peak(samples = 14 width =     13.0 mus , energy =    242.7 pes
#         height =     42.5 pes tmin-tmax = minmax(min=540.5, max=553.5) mus
# peak number = 0: sipm number = 607
#     sipm waveform (zs) = Peak(samples = 16 width =     15.0 mus , energy =    284.8 pes
#         height =     47.8 pes tmin-tmax = minmax(min=539.5, max=554.5) mus
# peak number = 0: sipm number = 613
#     sipm waveform (zs) = Peak(samples = 12 width =     11.0 mus , energy =     68.2 pes
#         height =     12.0 pes tmin-tmax = minmax(min=541.5, max=552.5) mus
# peak number = 0: sipm number = 614
#     sipm waveform (zs) = Peak(samples = 15 width =     14.0 mus , energy =    226.0 pes
#         height =     32.7 pes tmin-tmax = minmax(min=540.5, max=554.5) mus
# peak number = 0: sipm number = 615
#     sipm waveform (zs) = Peak(samples = 16 width =     16.0 mus , energy =    293.6 pes
#         height =     39.8 pes tmin-tmax = minmax(min=539.5, max=555.5) mus
# peak number = 0: sipm number = 621
#     sipm waveform (zs) = Peak(samples = 8 width =     10.0 mus , energy =     27.1 pes
#         height =      5.8 pes tmin-tmax = minmax(min=542.5, max=552.5) mus
# peak number = 0: sipm number = 622
#     sipm waveform (zs) = Peak(samples = 11 width =     10.0 mus , energy =     81.3 pes
#         height =     12.9 pes tmin-tmax = minmax(min=542.5, max=552.5) mus
# peak number = 0: sipm number = 623
#     sipm waveform (zs) = Peak(samples = 11 width =     12.0 mus , energy =     57.4 pes
#         height =     11.0 pes tmin-tmax = minmax(min=540.5, max=552.5) mus
# ================================================================================
# 1

# %%
event = 3
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      0.2 mus , energy =     40.1 pes
#         height =      6.3 pes tmin-tmax = minmax(min=100.075, max=100.25) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 10 width =      8.7 mus , energy =  19738.3 pes
#         height =   5236.8 pes tmin-tmax = minmax(min=252.6625, max=261.325) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 10 width =      8.7 mus , energy =  19738.3 pes
#         height =   5236.8 pes tmin-tmax = minmax(min=252.6625, max=261.325) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (689, 696, 697, 698, 699, 1024, 1025, 1026, 1027, 1032, 1033, 1034, 1035)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 689
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     15.2 pes
#         height =      5.0 pes tmin-tmax = minmax(min=254.5, max=258.5) mus
# peak number = 0: sipm number = 696
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     26.7 pes
#         height =      7.6 pes tmin-tmax = minmax(min=254.5, max=258.5) mus
# peak number = 0: sipm number = 697
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =    160.8 pes
#         height =     45.9 pes tmin-tmax = minmax(min=253.5, max=259.5) mus
# peak number = 0: sipm number = 698
#     sipm waveform (zs) = Peak(samples = 8 width =      6.8 mus , energy =    162.0 pes
#         height =     44.9 pes tmin-tmax = minmax(min=252.6625, max=259.5) mus
# peak number = 0: sipm number = 699
#     sipm waveform (zs) = Peak(samples = 4 width =      3.0 mus , energy =     25.9 pes
#         height =      9.9 pes tmin-tmax = minmax(min=254.5, max=257.5) mus
# peak number = 0: sipm number = 1024
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     69.6 pes
#         height =     20.8 pes tmin-tmax = minmax(min=253.5, max=258.5) mus
# peak number = 0: sipm number = 1025
#     sipm waveform (zs) = Peak(samples = 8 width =      6.8 mus , energy =    507.1 pes
#         height =    144.4 pes tmin-tmax = minmax(min=252.6625, max=259.5) mus
# peak number = 0: sipm number = 1026
#     sipm waveform (zs) = Peak(samples = 9 width =      7.8 mus , energy =    507.7 pes
#         height =    147.7 pes tmin-tmax = minmax(min=252.6625, max=260.5) mus
# peak number = 0: sipm number = 1027
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     63.2 pes
#         height =     20.9 pes tmin-tmax = minmax(min=253.5, max=258.5) mus
# peak number = 0: sipm number = 1032
#     sipm waveform (zs) = Peak(samples = 4 width =      3.0 mus , energy =     36.4 pes
#         height =     16.1 pes tmin-tmax = minmax(min=254.5, max=257.5) mus
# peak number = 0: sipm number = 1033
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =    167.4 pes
#         height =     41.9 pes tmin-tmax = minmax(min=253.5, max=258.5) mus
# peak number = 0: sipm number = 1034
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =    152.0 pes
#         height =     40.9 pes tmin-tmax = minmax(min=253.5, max=258.5) mus
# peak number = 0: sipm number = 1035
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     33.7 pes
#         height =      9.0 pes tmin-tmax = minmax(min=254.5, max=258.5) mus
# ================================================================================
# 1

# %%
event = 4
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      0.2 mus , energy =      7.6 pes
#         height =      1.2 pes tmin-tmax = minmax(min=100.10000000000001, max=100.275) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      6.4 mus , energy =   4322.4 pes
#         height =   1212.3 pes tmin-tmax = minmax(min=257.75, max=264.1625) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      6.4 mus , energy =   4322.4 pes
#         height =   1212.3 pes tmin-tmax = minmax(min=257.75, max=264.1625) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1436, 1437, 1438, 1444, 1445)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1436
#     sipm waveform (zs) = Peak(samples = 6 width =      4.8 mus , energy =     84.4 pes
#         height =     29.9 pes tmin-tmax = minmax(min=257.75, max=262.5) mus
# peak number = 0: sipm number = 1437
#     sipm waveform (zs) = Peak(samples = 6 width =      4.8 mus , energy =    116.0 pes
#         height =     40.9 pes tmin-tmax = minmax(min=257.75, max=262.5) mus
# peak number = 0: sipm number = 1438
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     22.9 pes
#         height =      6.0 pes tmin-tmax = minmax(min=258.5, max=262.5) mus
# peak number = 0: sipm number = 1444
#     sipm waveform (zs) = Peak(samples = 7 width =      5.8 mus , energy =     63.4 pes
#         height =     22.0 pes tmin-tmax = minmax(min=257.75, max=263.5) mus
# peak number = 0: sipm number = 1445
#     sipm waveform (zs) = Peak(samples = 6 width =      4.8 mus , energy =     72.2 pes
#         height =     22.8 pes tmin-tmax = minmax(min=257.75, max=262.5) mus
# ================================================================================
# 1

# %%
event = 5
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 13 width =      0.3 mus , energy =     79.0 pes
#         height =     10.2 pes tmin-tmax = minmax(min=100.075, max=100.375) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 18 width =     16.2 mus , energy =  19422.4 pes
#         height =   2883.1 pes tmin-tmax = minmax(min=400.9875, max=417.1625) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 18 width =     16.2 mus , energy =  19422.4 pes
#         height =   2883.1 pes tmin-tmax = minmax(min=400.9875, max=417.1625) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (545, 546, 552, 553, 554, 555, 560, 561, 562, 563, 568, 569, 570, 631, 639, 896, 897)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 545
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     33.5 pes
#         height =      8.0 pes tmin-tmax = minmax(min=406.5, max=412.5) mus
# peak number = 0: sipm number = 546
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     32.5 pes
#         height =     11.9 pes tmin-tmax = minmax(min=406.5, max=410.5) mus
# peak number = 0: sipm number = 552
#     sipm waveform (zs) = Peak(samples = 9 width =      8.0 mus , energy =    108.0 pes
#         height =     21.6 pes tmin-tmax = minmax(min=404.5, max=412.5) mus
# peak number = 0: sipm number = 553
#     sipm waveform (zs) = Peak(samples = 11 width =     10.0 mus , energy =    275.1 pes
#         height =     49.3 pes tmin-tmax = minmax(min=404.5, max=414.5) mus
# peak number = 0: sipm number = 554
#     sipm waveform (zs) = Peak(samples = 10 width =      9.0 mus , energy =    139.5 pes
#         height =     29.8 pes tmin-tmax = minmax(min=404.5, max=413.5) mus
# peak number = 0: sipm number = 555
#     sipm waveform (zs) = Peak(samples = 5 width =      6.0 mus , energy =     22.1 pes
#         height =      7.1 pes tmin-tmax = minmax(min=407.5, max=413.5) mus
# peak number = 0: sipm number = 560
#     sipm waveform (zs) = Peak(samples = 15 width =     13.5 mus , energy =    190.3 pes
#         height =     28.9 pes tmin-tmax = minmax(min=400.9875, max=414.5) mus
# peak number = 0: sipm number = 561
#     sipm waveform (zs) = Peak(samples = 13 width =     12.0 mus , energy =    545.6 pes
#         height =     83.4 pes tmin-tmax = minmax(min=403.5, max=415.5) mus
# peak number = 0: sipm number = 562
#     sipm waveform (zs) = Peak(samples = 11 width =     10.0 mus , energy =    296.3 pes
#         height =     53.8 pes tmin-tmax = minmax(min=404.5, max=414.5) mus
# peak number = 0: sipm number = 563
#     sipm waveform (zs) = Peak(samples = 9 width =      9.0 mus , energy =     47.3 pes
#         height =      9.9 pes tmin-tmax = minmax(min=405.5, max=414.5) mus
# peak number = 0: sipm number = 568
#     sipm waveform (zs) = Peak(samples = 13 width =     14.0 mus , energy =    138.1 pes
#         height =     26.0 pes tmin-tmax = minmax(min=401.5, max=415.5) mus
# peak number = 0: sipm number = 569
#     sipm waveform (zs) = Peak(samples = 16 width =     15.0 mus , energy =    259.1 pes
#         height =     39.9 pes tmin-tmax = minmax(min=401.5, max=416.5) mus
# peak number = 0: sipm number = 570
#     sipm waveform (zs) = Peak(samples = 13 width =     12.0 mus , energy =    142.7 pes
#         height =     25.9 pes tmin-tmax = minmax(min=403.5, max=415.5) mus
# peak number = 0: sipm number = 631
#     sipm waveform (zs) = Peak(samples = 6 width =      7.0 mus , energy =     24.4 pes
#         height =      6.9 pes tmin-tmax = minmax(min=403.5, max=410.5) mus
# peak number = 0: sipm number = 639
#     sipm waveform (zs) = Peak(samples = 7 width =      9.0 mus , energy =     22.9 pes
#         height =      5.9 pes tmin-tmax = minmax(min=403.5, max=412.5) mus
# peak number = 0: sipm number = 896
#     sipm waveform (zs) = Peak(samples = 7 width =      8.0 mus , energy =     36.6 pes
#         height =      9.0 pes tmin-tmax = minmax(min=402.5, max=410.5) mus
# peak number = 0: sipm number = 897
#     sipm waveform (zs) = Peak(samples = 12 width =     12.0 mus , energy =     42.0 pes
#         height =      7.1 pes tmin-tmax = minmax(min=402.5, max=414.5) mus
# ================================================================================
# 1
