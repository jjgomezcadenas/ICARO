# %%
import os
import datetime
print(datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S'))

import time
import glob
import tables as tb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
# Out:
# 2017-07-25 20:34:36

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

plt.rcParams["figure.figsize"] = 10, 8
plt.rcParams["font.size"     ] = 14

# %%
from invisible_cities.database import load_db

import invisible_cities.sierpe.blr as blr

import invisible_cities.reco.tbl_functions as tbl
import invisible_cities.reco.peak_functions as pf
import invisible_cities.reco.peak_functions_c as cpf

from   invisible_cities.evm.ic_containers           import S12Params 
from   invisible_cities.evm.ic_containers          import CalibVectors
from   invisible_cities.evm.ic_containers          import DeconvParams
from   invisible_cities.evm.ic_containers          import ThresholdParams

from   invisible_cities.core.system_of_units_c import units
from   invisible_cities.types.ic_types import minmax
from   invisible_cities.types.ic_types import Counter
import invisible_cities.icaro.mpl_functions as mpl
from invisible_cities.icaro.pmaps_mpl import plot_s12
from invisible_cities.icaro.pmaps_mpl import plot_s2si_map

# %%
import invisible_cities.icaro.mpl_functions as mpl

# %%
import invisible_cities.evm.event_model as evm

# %%
from invisible_cities.evm.pmaps import S12
from invisible_cities.evm.pmaps import S1
from invisible_cities.evm.pmaps import S2
from invisible_cities.evm.pmaps import S2Si

# %%
from invisible_cities.core.exceptions        import SipmEmptyList
from invisible_cities.core.exceptions        import SipmNotFound
from invisible_cities.core.exceptions        import PeakNotFound

# %%
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)

# %%
run_number = -4446
DataPMT = load_db.DataPMT(run_number)
DataSiPM = load_db.DataSiPM(run_number)
xs = DataSiPM.X.values
ys = DataSiPM.Y.values
pmt_active = np.nonzero(DataPMT.Active.values)[0].tolist()

# %%
channel_id = DataPMT.ChannelID.values
coeff_blr = abs(DataPMT.coeff_blr.values)
coeff_c = abs(DataPMT.coeff_c .values)
adc_to_pes = abs(DataPMT.adc_to_pes.values)
adc_to_pes_sipm = abs(DataSiPM.adc_to_pes.values)

# %%
DataPMT
# Out:
#     SensorID  ChannelID PmtID  Active         X         Y  coeff_blr  \
# 0          0         18  PMT1       1  -23.9414   65.7785   0.000788
# 1          1         22  PMT3       1  -44.9951  -53.6231   0.000789
# 2          2         19  PMT2       1   68.9365  -12.1554   0.000775
# 3          3         23  PMT4       1    0.0000  185.0000   0.000778
# 4          4          9  PMTC       1 -118.9160  141.7180   0.000789
# 5          5          8  PMTB       1 -182.1890   32.1249   0.000781
# 6          6          5  PMTA       1 -160.2150  -92.5000   0.000794
# 7          7          4  PMT9       1  -63.2737 -173.8430   0.000773
# 8          8          1  PMT8       1   63.2737 -173.8430   0.000788
# 9         10         31  PMT6       1  182.1890   32.1249   0.000782
# 10        11         30  PMT5       1  118.9160  141.7180   0.000777
# 11         9          0  PMT7       0  160.2150  -92.5000   0.000787
#
#      coeff_c  adc_to_pes  noise_rms     Sigma
# 0   0.000002     25.7701       0.75  10.84930
# 1   0.000002     26.8967       0.78  11.93490
# 2   0.000002     27.8411       0.75  10.47710
# 3   0.000002     28.4480       0.73  10.95000
# 4   0.000002     30.4163       0.80  11.23310
# 5   0.000002     24.0598       0.78   8.40781
# 6   0.000002     26.7696       0.76   9.75851
# 7   0.000002     37.4034       0.77  14.01940
# 8   0.000002     24.7545       0.81   9.19441
# 9   0.000002     21.6441       0.79   7.69790
# 10  0.000002     24.3859       0.79   8.87084
# 11  0.000002      0.0000       0.77   0.00000

# %%
RWF_file = os.path.join(os.environ['IC_DATA'], 'MC_PreProd_July_2017',
                        'dst_NEXT_v1_00_05_Kr_ACTIVE_0_0_7bar_RWF_10.h5')
print('RWF file = {}'.format(RWF_file))
# Out:
# RWF file = /Users/jjgomezcadenas/Projects/ICDATA/MC_PreProd_July_2017/dst_NEXT_v1_00_05_Kr_ACTIVE_0_0_7bar_RWF_10.h5

# %%
h5rwf = tb.open_file(RWF_file,'r')

# %%
pmtrwf, pmtblr, sipmrwf = tbl.get_vectors(h5rwf)
NEVT, pmtrwf, sipmrwf, _ = tbl.get_rwf_vectors(h5rwf)
sp = tbl.get_sensor_params_from_vectors(pmtrwf, sipmrwf)
print(sp)
# Out:
# ####################
# SensorParams
# ####################
# npmt: 12
# pmtwl: 48000
# nsipm: 1792
# sipmwl: 1200

# %% [markdown]
# ### Reconstruction Parameters

# %%
calib_vectors = CalibVectors(channel_id = DataPMT.ChannelID.values,
                             coeff_blr = abs(DataPMT.coeff_blr   .values),
                             coeff_c = abs(DataPMT.coeff_c   .values),
                             adc_to_pes = DataPMT.adc_to_pes.values,
                             adc_to_pes_sipm = DataSiPM.adc_to_pes.values,
                             pmt_active = np.nonzero(DataPMT.Active.values)[0].tolist())


deconv_params = DeconvParams(n_baseline = 45000,
                              thr_trigger = 5)

s1par = S12Params(time = minmax(min    = 99 * units.mus,
                           max    = 101 * units.mus),
                           stride = 4,
                           length = minmax(min = 6, max = 20),  #150 ns -- 500 ns
                           rebin  = False)

s2par = S12Params(time = minmax(min    = 101 * units.mus,
                           max    = 1199 * units.mus),
                           stride = 40,
                           length = minmax(min = 120, max = 1e5),  # 4 mus --
                           rebin  = True)

thresholds = ThresholdParams(thr_s1=0.5 * units.pes,
                      thr_s2=1.0 * units.pes,
                      thr_MAU=3*units.adc,
                      thr_sipm=1.5*units.pes,
                      thr_SIPM=15*units.pes)

# %%
event = 0

# %%
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))

# %% [markdown]
# #### Deconvolution

# %%
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)

# %% [markdown]
# #### csum

# %%
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)

# %%
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))

# %% [markdown]
# #### S1 and S2

# %%
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)

# %%
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())

# %%
s1
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 14 width =      0.3 mus , energy =     17.5 pes
#         height =      2.4 pes tmin-tmax = minmax(min=100.075, max=100.4) mus

# %%
plot_s12(s1)

# %%
s2
# Out:
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 12 width =     10.7 mus , energy =   2775.5 pes
#         height =    477.3 pes tmin-tmax = minmax(min=619.6750000000001, max=630.325) mus

# %%
plot_s12(s2)

# %% [markdown]
# #### S2Si

# %%
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)

# %%
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)

# %%
s2si
# Out:
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 12 width =     10.7 mus , energy =   2775.5 pes
#         height =    477.3 pes tmin-tmax = minmax(min=619.6750000000001, max=630.325) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1517, 1518, 1525, 1526, 1527, 1533, 1534)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1517
#     sipm waveform (zs) = Peak(samples = 9 width =      7.8 mus , energy =     30.8 pes
#         height =      5.1 pes tmin-tmax = minmax(min=619.6750000000001, max=627.5) mus
# peak number = 0: sipm number = 1518
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     18.8 pes
#         height =      5.8 pes tmin-tmax = minmax(min=622.5, max=626.5) mus
# peak number = 0: sipm number = 1525
#     sipm waveform (zs) = Peak(samples = 7 width =      7.0 mus , energy =     39.5 pes
#         height =      9.0 pes tmin-tmax = minmax(min=620.5, max=627.5) mus
# peak number = 0: sipm number = 1526
#     sipm waveform (zs) = Peak(samples = 8 width =      8.8 mus , energy =     62.0 pes
#         height =     12.8 pes tmin-tmax = minmax(min=621.5, max=630.325) mus
# peak number = 0: sipm number = 1527
#     sipm waveform (zs) = Peak(samples = 6 width =      6.0 mus , energy =     18.3 pes
#         height =      4.1 pes tmin-tmax = minmax(min=621.5, max=627.5) mus
# peak number = 0: sipm number = 1533
#     sipm waveform (zs) = Peak(samples = 5 width =      5.0 mus , energy =     21.8 pes
#         height =      7.0 pes tmin-tmax = minmax(min=621.5, max=626.5) mus
# peak number = 0: sipm number = 1534
#     sipm waveform (zs) = Peak(samples = 7 width =      8.0 mus , energy =     24.9 pes
#         height =      6.0 pes tmin-tmax = minmax(min=621.5, max=629.5) mus
# ================================================================================

# %%
def draw_pmt_map(celid, xpmt,ypmt, sel=None):
    fig, ax = plt.subplots()
    plt.plot(xpmt, ypmt, 'o')
    cid = [str(c) for c in celid]
    
    for c, x,y in zip(cid, xpmt,ypmt):
        xy = (x,y)
        offsetbox = TextArea(c, minimumdescent=False)
        ab = AnnotationBbox(offsetbox, xy)
    
        if int(c) in sel:
            ab = AnnotationBbox(offsetbox, xy)
            ax.add_artist(ab)

    plt.show()

# %%
s2si.number_of_peaks
# Out:
# 1

# %%
s2si.sipms_in_peak(0)
# Out:
# (1517, 1518, 1525, 1526, 1527, 1533, 1534)

# %%
plot_s2si_map(s2si, run_number=-4446)

# %%
event = 1
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      0.2 mus , energy =     15.3 pes
#         height =      2.9 pes tmin-tmax = minmax(min=100.05, max=100.22500000000001) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 11 width =      9.7 mus , energy =   3693.3 pes
#         height =    741.0 pes tmin-tmax = minmax(min=515.675, max=525.35) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 11 width =      9.7 mus , energy =   3693.3 pes
#         height =    741.0 pes tmin-tmax = minmax(min=515.675, max=525.35) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (688, 696, 697, 1024, 1025, 1026)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 688
#     sipm waveform (zs) = Peak(samples = 6 width =      5.0 mus , energy =     17.3 pes
#         height =      4.0 pes tmin-tmax = minmax(min=517.5, max=522.5) mus
# peak number = 0: sipm number = 696
#     sipm waveform (zs) = Peak(samples = 6 width =      6.0 mus , energy =     36.8 pes
#         height =     10.0 pes tmin-tmax = minmax(min=516.5, max=522.5) mus
# peak number = 0: sipm number = 697
#     sipm waveform (zs) = Peak(samples = 9 width =      8.8 mus , energy =     42.1 pes
#         height =     11.0 pes tmin-tmax = minmax(min=515.675, max=524.5) mus
# peak number = 0: sipm number = 1024
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     52.0 pes
#         height =     13.6 pes tmin-tmax = minmax(min=517.5, max=523.5) mus
# peak number = 0: sipm number = 1025
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =     54.5 pes
#         height =     12.9 pes tmin-tmax = minmax(min=517.5, max=524.5) mus
# peak number = 0: sipm number = 1026
#     sipm waveform (zs) = Peak(samples = 6 width =      6.0 mus , energy =     18.9 pes
#         height =      6.0 pes tmin-tmax = minmax(min=517.5, max=523.5) mus
# ================================================================================
# 1

# %%
event = 2
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 6 width =      0.1 mus , energy =      8.1 pes
#         height =      1.8 pes tmin-tmax = minmax(min=100.075, max=100.2) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 10 width =      8.7 mus , energy =   3441.2 pes
#         height =    809.2 pes tmin-tmax = minmax(min=383.77500000000003, max=392.45) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 10 width =      8.7 mus , energy =   3441.2 pes
#         height =    809.2 pes tmin-tmax = minmax(min=383.77500000000003, max=392.45) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (776, 777, 784, 785, 792, 855)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 776
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     54.9 pes
#         height =     24.0 pes tmin-tmax = minmax(min=384.5, max=390.5) mus
# peak number = 0: sipm number = 777
#     sipm waveform (zs) = Peak(samples = 4 width =      3.0 mus , energy =     17.5 pes
#         height =      4.8 pes tmin-tmax = minmax(min=386.5, max=389.5) mus
# peak number = 0: sipm number = 784
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     97.7 pes
#         height =     23.9 pes tmin-tmax = minmax(min=384.5, max=390.5) mus
# peak number = 0: sipm number = 785
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     38.0 pes
#         height =      9.6 pes tmin-tmax = minmax(min=385.5, max=389.5) mus
# peak number = 0: sipm number = 792
#     sipm waveform (zs) = Peak(samples = 4 width =      3.0 mus , energy =     22.6 pes
#         height =      7.9 pes tmin-tmax = minmax(min=385.5, max=388.5) mus
# peak number = 0: sipm number = 855
#     sipm waveform (zs) = Peak(samples = 6 width =      6.0 mus , energy =     35.4 pes
#         height =     10.9 pes tmin-tmax = minmax(min=385.5, max=391.5) mus
# ================================================================================
# 1

# %%
event = 3
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 0)
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      6.2 mus , energy =   4327.0 pes
#         height =   1251.7 pes tmin-tmax = minmax(min=232.9625, max=239.1875) mus
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-39-9b24ac5d4c47> in <module>()
#      22 print(s1)
#      23 print(s2)
# ---> 24 plot_s12(s1)
#      25 plot_s12(s2)
#      26 sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
#
# /Users/jjgomezcadenas/Projects/IC/invisible_cities/icaro/pmaps_mpl.py in plot_s12(s12, figsize)
#      32         x = 3
#      33         y = xy/x
# ---> 34         if y % xy != 0:
#      35             y = int(xy/x) + 1
#      36         for i in range(xy):
#
# ZeroDivisionError: float modulo

# %%
event = 4
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      0.2 mus , energy =      7.6 pes
#         height =      1.2 pes tmin-tmax = minmax(min=100.10000000000001, max=100.275) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      6.4 mus , energy =   4322.4 pes
#         height =   1212.3 pes tmin-tmax = minmax(min=257.75, max=264.1625) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 8 width =      6.4 mus , energy =   4322.4 pes
#         height =   1212.3 pes tmin-tmax = minmax(min=257.75, max=264.1625) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1436, 1437, 1438, 1444, 1445)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1436
#     sipm waveform (zs) = Peak(samples = 6 width =      4.8 mus , energy =     84.4 pes
#         height =     29.9 pes tmin-tmax = minmax(min=257.75, max=262.5) mus
# peak number = 0: sipm number = 1437
#     sipm waveform (zs) = Peak(samples = 6 width =      4.8 mus , energy =    116.0 pes
#         height =     40.9 pes tmin-tmax = minmax(min=257.75, max=262.5) mus
# peak number = 0: sipm number = 1438
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     22.9 pes
#         height =      6.0 pes tmin-tmax = minmax(min=258.5, max=262.5) mus
# peak number = 0: sipm number = 1444
#     sipm waveform (zs) = Peak(samples = 7 width =      5.8 mus , energy =     63.4 pes
#         height =     22.0 pes tmin-tmax = minmax(min=257.75, max=263.5) mus
# peak number = 0: sipm number = 1445
#     sipm waveform (zs) = Peak(samples = 6 width =      4.8 mus , energy =     72.2 pes
#         height =     22.8 pes tmin-tmax = minmax(min=257.75, max=262.5) mus
# ================================================================================
# 1

# %%
event = 5
mpl.plot_pmt_waveforms(pmtrwf[event], zoom=False, window_size=1200, figsize=(10,10))
CWF = blr.deconv_pmt(pmtrwf[event], coeff_c, coeff_blr,
                         pmt_active  = pmt_active,
                         n_baseline  = deconv_params.n_baseline,
                         thr_trigger = deconv_params.thr_trigger)
csum, csum_mau = cpf.calibrated_pmt_sum(CWF,
                                            adc_to_pes,
                                            pmt_active  = pmt_active,
                                            n_MAU       = 100,
                                            thr_MAU     = thresholds.thr_MAU)
mpl.plot_signal_vs_time_mus(csum,
                        t_min      = 0,
                        t_max      = 1300,
                        signal_min =    -10,
                        signal_max =  30,
                        figsize=(6,6))
s2_ene, s2_indx = cpf.wfzs(csum, threshold=thresholds.thr_s2)
s1_ene, s1_indx = cpf.wfzs(csum_mau, threshold=thresholds.thr_s1)
s1 = cpf.find_s1(csum, s1_indx, **s1par._asdict())
s2 = cpf.find_s2(csum, s2_indx, **s2par._asdict())
print(s1)
print(s2)
plot_s12(s1)
plot_s12(s2)
sipmzs= cpf.signal_sipm(sipmrwf[event], adc_to_pes_sipm,
                           thr=thresholds.thr_sipm, n_MAU=100)
s2si = cpf.find_s2si(sipmzs, s2.s2d, thr = thresholds.thr_SIPM)
print(s2si)
print(s2si.number_of_peaks)
plot_s2si_map(s2si, run_number=-4446)
# Out:
# S1 (number of peaks = 1)
# peak number = 0: Peak(samples = 7 width =      0.1 mus , energy =     14.9 pes
#         height =      2.8 pes tmin-tmax = minmax(min=100.075, max=100.22500000000001) mus
#
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 11 width =      9.4 mus , energy =   3372.0 pes
#         height =    689.1 pes tmin-tmax = minmax(min=496.96250000000003, max=506.325) mus
#
# ================================================================================
# S2 (number of peaks = 1)
# peak number = 0: Peak(samples = 11 width =      9.4 mus , energy =   3372.0 pes
#         height =    689.1 pes tmin-tmax = minmax(min=496.96250000000003, max=506.325) mus
# --------------------------------------------------------------------------------
# SiPMs for non-empty peaks
#
# peak number = 0: nsipm in peak = (1493, 1494, 1501, 1502, 1503, 1509, 1510, 1511)
# --------------------------------------------------------------------------------
# SiPMs Waveforms
#
# peak number = 0: sipm number = 1493
#     sipm waveform (zs) = Peak(samples = 5 width =      5.0 mus , energy =     16.6 pes
#         height =      5.0 pes tmin-tmax = minmax(min=498.5, max=503.5) mus
# peak number = 0: sipm number = 1494
#     sipm waveform (zs) = Peak(samples = 5 width =      4.0 mus , energy =     19.5 pes
#         height =      7.8 pes tmin-tmax = minmax(min=499.5, max=503.5) mus
# peak number = 0: sipm number = 1501
#     sipm waveform (zs) = Peak(samples = 8 width =      8.5 mus , energy =     48.6 pes
#         height =     13.0 pes tmin-tmax = minmax(min=496.96250000000003, max=505.5) mus
# peak number = 0: sipm number = 1502
#     sipm waveform (zs) = Peak(samples = 6 width =      6.0 mus , energy =     71.6 pes
#         height =     20.8 pes tmin-tmax = minmax(min=497.5, max=503.5) mus
# peak number = 0: sipm number = 1503
#     sipm waveform (zs) = Peak(samples = 4 width =      4.0 mus , energy =     20.2 pes
#         height =      7.8 pes tmin-tmax = minmax(min=498.5, max=502.5) mus
# peak number = 0: sipm number = 1509
#     sipm waveform (zs) = Peak(samples = 7 width =      6.0 mus , energy =     34.6 pes
#         height =      8.8 pes tmin-tmax = minmax(min=498.5, max=504.5) mus
# peak number = 0: sipm number = 1510
#     sipm waveform (zs) = Peak(samples = 8 width =      7.0 mus , energy =     66.4 pes
#         height =     17.9 pes tmin-tmax = minmax(min=498.5, max=505.5) mus
# peak number = 0: sipm number = 1511
#     sipm waveform (zs) = Peak(samples = 5 width =      7.0 mus , energy =     17.1 pes
#         height =      5.1 pes tmin-tmax = minmax(min=498.5, max=505.5) mus
# ================================================================================
# 1
